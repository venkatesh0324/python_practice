# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatesh0324/python_practice/blob/main/oracle_sql_live.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.2.2

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 100])
ypoints = np.array([0, 200])

plt.plot(xpoints, ypoints,)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints =np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 20, 1, 112, 5, 7])

plt.plot(ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,20,11])
plt.plot(ypoints,'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 7, 5,1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
ypoints=np.array([2,3,7,10,25,5])
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np  
ypoints=np.array([2,5,7,9,25,34])
plt.plot(ypoints,linestyle='dashdot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2=np.array([6,5,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
#bargraph representation 
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color='#ff8080' )
plt.show()

# %%
#pie chart respresenting marks
import matplotlib.pyplot as plt
import numpy as np

y = np.array([68, 66, 93, 97])
mylabels = ["single variable","several variables","english","evpr"]
mycolours=["#009999","#a31aff","#e60000","#cc2900"]

plt.pie(y, labels = mylabels,colors=mycolours)

plt.pie(y)
plt.show()
