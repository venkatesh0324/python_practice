# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatesh0324/python_practice/blob/main/exam_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Write Python code to generate labels for Time Table taking inputs x coordinate: hours and y coordinate as Subjects generate dotted line graph taking inputs Random.
import matplotlib.pyplot as plt
import numpy as np
xpoints=([])
ypoints=([])

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylables=["cse","mech","civil","ece"]
plt.pie(y, labels= mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

xpoints = np.array([0.0,1.0,2.0,2.5,3.0])

ypoints = np.array([2,4,6,8,10]) 

plt.plot(xpoints, ypoints) 

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["python", "chemistry", "english", "maths"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()
